# %%
# 필요한 라이브러리
import pandas as pd
import numpy as np
from pandas_gbq import to_gbq
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# # 광고목록

# %%
# 광고목록 파일 경로 
path_sh = "/Users/t2023-m0052/Documents/GitHub/final_project/data/IVE_광고목록.csv" # 세희
ad_list = pd.read_csv(path_sh, low_memory= False)
ad_list.head()
# Out:
#    ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  ads_category  \
# 0      160  tr71opm6C1        6       10    13604         1             1
# 1      284  xlNpfkgtLX        6       10    13605         1             1
# 2      292  7Hj8V5QKiy        6       10    13606         1             1
# 3      304  1RfxHJcuEe        6       10    13607         2             1
# 4      306  l3GyilYEVk        6       10    23543         1             1
#
#                ads_name                                         ads_search  \
# 0              리니지레드나이츠  리니지레드나이츠,com.ncsoft.redknights,ecaab3f9d2616f6...
# 1  강철의함대:Ocean Overlord  강철의함대:Ocean Overlord,com.gamepub.lw.g,a370ab70...
# 2              스노우 SNOW  스노우 SNOW,com.campmobile.snow,5b892d7e0cff73621...
# 3       서머너즈 워: 천공의 아레나  서머너즈 워: 천공의 아레나,com.com2us.smon.normal.freeful...
# 4                  하이마트  하이마트,com.himart.main,8230c6a95581533fad10b0e3b...
#
#                                         ads_icon_img  ... ads_age_min  \
# 0  https://lh3.googleusercontent.com/oDGXxngO9oOP...  ...           0
# 1  http://nextapps-nas.aws.appang.kr/icon/2016122...  ...           0
# 2  http://nextapps-nas.aws.appang.kr/icon/2016092...  ...           0
# 3  http://nextapps-nas.aws.appang.kr/icon/EecpHzP...  ...           0
# 4  http://nextapps-nas.aws.appang.kr/icon/2016032...  ...           0
#
#   ads_age_max ads_os_type ads_contract_price ads_reward_price ads_order  \
# 0         100           2                170              150    982800
# 1         100           2                180              160    987200
# 2         100           2                160              160    987300
# 3         100           2                230              210    931000
# 4         100           2                170              140   1155100
#
#   ads_rejoin_type ads_require_adid              regdate delyn
# 0            NONE                Y  2017-04-06 13:19:53     N
# 1            NONE                Y  2017-01-10 10:37:22     N
# 2            NONE                Y  2017-01-02 12:51:34     N
# 3            NONE                Y  2017-03-30 17:05:23     N
# 4            NONE                Y  2017-06-12 15:24:46     N
#
# [5 rows x 30 columns]

# %%
ad_list.isnull().sum()
# Out:
# ads_idx                    0
# ads_code                   0
# aff_idx                    0
# adv_idx                    0
# sch_idx                    0
# ads_type                   0
# ads_category               0
# ads_name                   0
# ads_search                 2
# ads_icon_img               5
# ads_summary             7061
# ads_guide                303
# ads_limit             444717
# ads_payment           442925
# ads_save_way             514
# ads_day_cap                0
# ads_sdate                  0
# ads_edate                  0
# ads_package           433998
# ads_sex_type          445250
# ads_age_min                0
# ads_age_max                0
# ads_os_type                0
# ads_contract_price         0
# ads_reward_price           0
# ads_order                  0
# ads_rejoin_type            0
# ads_require_adid           0
# regdate                    0
# delyn                      0
# dtype: int64

# %%
# 삭제된 광고 확인
ad_list.loc[ad_list['delyn'] == 'Y', ['ads_type', 'ads_name', 'ads_sdate', 'ads_edate', 'regdate']]
# Out:
#         ads_type                      ads_name            ads_sdate  \
# 7              3  데저트스톰_사전예약(desert_storm_cpa)  2016-12-28 15:42:00
# 14             1                        지하철종결자  0000-00-00 00:00:00
# 26             1                         메탈크래쉬  0000-00-00 00:00:00
# 456            3                     핀크 가입 이벤트  2017-12-08 15:00:00
# 475            1                        변호사님닷컴  0000-00-00 00:00:00
# ...          ...                           ...                  ...
# 439413         3              [클릭메이트-단골맺기] 홍선수  0000-00-00 00:00:00
# 440342         1                       초월자 키우기  0000-00-00 00:00:00
# 442692         1                  [원스토어] 조조의 꿈  2025-08-14 00:00:00
# 442693         2                         조조의 꿈  2025-08-14 00:00:00
# 443038         3              커넥트 CONNECT (여성)  0000-00-00 00:00:00
#
#                   ads_edate              regdate
# 7       2017-01-31 15:42:00  2017-01-05 11:31:16
# 14      0000-00-00 00:00:00  2017-01-11 16:47:10
# 26      0000-00-00 00:00:00  2017-01-19 18:34:22
# 456     2018-01-01 00:00:00  2017-12-08 15:06:55
# 475     0000-00-00 00:00:00  2017-12-15 13:21:11
# ...                     ...                  ...
# 439413  0000-00-00 00:00:00  2025-08-06 14:16:36
# 440342  0000-00-00 00:00:00  2025-08-08 16:54:36
# 442692  2025-09-02 00:00:00  2025-08-14 15:33:46
# 442693  2025-08-27 00:00:00  2025-08-14 15:33:53
# 443038  0000-00-00 00:00:00  2025-08-16 15:14:02
#
# [221 rows x 5 columns]

# %%
ad_list.columns
# Out:
# Index(['ads_idx', 'ads_code', 'aff_idx', 'adv_idx', 'sch_idx', 'ads_type',
#        'ads_category', 'ads_name', 'ads_search', 'ads_icon_img', 'ads_summary',
#        'ads_guide', 'ads_limit', 'ads_payment', 'ads_save_way', 'ads_day_cap',
#        'ads_sdate', 'ads_edate', 'ads_package', 'ads_sex_type', 'ads_age_min',
#        'ads_age_max', 'ads_os_type', 'ads_contract_price', 'ads_reward_price',
#        'ads_order', 'ads_rejoin_type', 'ads_require_adid', 'regdate', 'delyn'],
#       dtype='object')

# %% [markdown]
# ## 전처리

# %%
# 필요없는 열 제거
ad_list = ad_list.drop(['sch_idx', 'ads_search', 'ads_guide', 'ads_limit', 'ads_payment', 'ads_package', 'ads_sex_type', 'ads_require_adid'], axis=1)
# 앞에서 확인한 delyn: 삭제한 광고가 아닌 것만 가져오기
ad_list = ad_list[ad_list['delyn'] == 'N']
ad_list = ad_list.drop(['delyn'], axis=1)
# 등록 날짜 - 날짜 형식으로 변환
ad_list['regdate']   = pd.to_datetime(ad_list['regdate'])
ad_list
# Out:
#         ads_idx    ads_code  aff_idx  adv_idx  ads_type  ads_category  \
# 0           160  tr71opm6C1        6       10         1             1
# 1           284  xlNpfkgtLX        6       10         1             1
# 2           292  7Hj8V5QKiy        6       10         1             1
# 3           304  1RfxHJcuEe        6       10         2             1
# 4           306  l3GyilYEVk        6       10         1             1
# ...         ...         ...      ...      ...       ...           ...
# 445255   446914  qy1HUatIL9       85     1631         3             4
# 445256   446915  UKnGFJUnmg       84     1623         3             4
# 445257   446916  g3lUg3nuxR       86     1655         3             4
# 445258   446917  0GLHsRVZNv       57       84         3             8
# 445259   446918  k2YLVkNAuO       57       84         3             8
#
#                                                 ads_name  \
# 0                                               리니지레드나이츠
# 1                                   강철의함대:Ocean Overlord
# 2                                               스노우 SNOW
# 3                                        서머너즈 워: 천공의 아레나
# 4                                                   하이마트
# ...                                                  ...
# 445255                                        한식뷔페&카페 봄날
# 445256                                              용융소금
# 445257  1kg 원두커피 블렌드 7종 맛있는 당일로스팅 고소한 납품 도매 납품 홀빈 180244
# 445258                                       [가입하기] 슈퍼티비
# 445259                                       [가입하기] 나인티비
#
#                                              ads_icon_img  \
# 0       https://lh3.googleusercontent.com/oDGXxngO9oOP...
# 1       http://nextapps-nas.aws.appang.kr/icon/2016122...
# 2       http://nextapps-nas.aws.appang.kr/icon/2016092...
# 3       http://nextapps-nas.aws.appang.kr/icon/EecpHzP...
# 4       http://nextapps-nas.aws.appang.kr/icon/2016032...
# ...                                                   ...
# 445255                   https://i.imgur.com/XdcGFx7.jpeg
# 445256  https://adwize.co.kr/common_img/reward/GNSQ_IC...
# 445257            https://cashplan-r2.uk/quiz-mission.png
# 445258  https://s3.ap-northeast-2.amazonaws.com/com.ga...
# 445259  https://s3.ap-northeast-2.amazonaws.com/com.ga...
#
#                                               ads_summary  ads_save_way  ...  \
# 0       [앱설명]<br />[설치형] 매력만점 영웅들과 소환수들이 함께하는 취향저격 RPG...            받기  ...
# 1       [앱설명]<br />[설치형] 한, 중, 일 아시아 유저들과 함께 대규모 해상 전투...            받기  ...
# 2       [앱설명]<br />[설치형] 셀카, 얼굴인식 스티커, 꿀잼 카메라<br /><br...            받기  ...
# 3       [앱설명]<br />[실행형] 전 세계 5000만 소환사들을 사로잡은 명작 RPG<...         최초 오픈  ...
# 4                                     새롭게 단장한 하이마트 쇼핑몰 앱!            받기  ...
# ...                                                   ...           ...  ...
# 445255  1.  가이드라인 대로 진행하지 않으시면, 매크로로 인식하여 추후 문제가 발생할 수...          정답입력  ...
# 445256  [참여방법]\n- 미션 참여 방법을 꼭 확인하신 후 참여해 주세요.\n- 제공되는 ...        퀴즈 맞추기  ...
# 445257  [참여방법]\n1. 본문에서 퀴즈와 상품/장소 확인\n1-1. 퀴즈: 7번째 태그 ...  네이버스마트스토어 퀴즈  ...
# 445258  1. 회원가입하기 \n**성인인증 받을필요는 없음❌\n\n2. 왼쪽상단 메뉴바 클릭...            참여  ...
# 445259  1. 회원가입하기\n**성인인증 받을필요는 없음❌\n\n2. 왼쪽상단 메뉴바 클릭 ...            참여  ...
#
#                   ads_sdate            ads_edate ads_age_min  ads_age_max  \
# 0       2016-12-01 00:00:00  9999-12-31 23:59:59           0          100
# 1       2016-12-29 00:00:00  9999-12-31 23:59:59           0          100
# 2       2016-12-29 00:00:00  9999-12-31 23:59:59           0          100
# 3       2017-01-01 00:00:00  9999-12-31 23:59:59           0          100
# 4       2017-01-01 00:00:00  2019-11-01 00:00:00           0          100
# ...                     ...                  ...         ...          ...
# 445255  2025-08-25 11:08:15  9999-12-31 23:59:59           0          100
# 445256  2025-08-25 11:12:12  9999-12-31 23:59:59           0          100
# 445257  2025-08-25 11:12:16  9999-12-31 23:59:59           0          100
# 445258  2025-08-25 11:00:00  2030-12-27 00:00:00           0          100
# 445259  2025-08-25 11:00:00  2030-12-27 00:00:00           0          100
#
#         ads_os_type  ads_contract_price  ads_reward_price  ads_order  \
# 0                 2                 170               150     982800
# 1                 2                 180               160     987200
# 2                 2                 160               160     987300
# 3                 2                 230               210     931000
# 4                 2                 170               140    1155100
# ...             ...                 ...               ...        ...
# 445255            7                  16                10    1369920
# 445256            7                  15                10    1369919
# 445257            7                  18                12    1369918
# 445258            7                 300               225    2764400
# 445259            7                 300               225    2764500
#
#               ads_rejoin_type             regdate
# 0                        NONE 2017-04-06 13:19:53
# 1                        NONE 2017-01-10 10:37:22
# 2                        NONE 2017-01-02 12:51:34
# 3                        NONE 2017-03-30 17:05:23
# 4                        NONE 2017-06-12 15:24:46
# ...                       ...                 ...
# 445255  ADS_CODE_DAILY_UPDATE 2025-08-25 11:08:15
# 445256                   NONE 2025-08-25 11:12:12
# 445257  ADS_CODE_DAILY_UPDATE 2025-08-25 11:12:16
# 445258                   NONE 2025-08-25 11:18:35
# 445259                   NONE 2025-08-25 11:18:54
#
# [445039 rows x 21 columns]

# %%
print(ad_list.loc[ad_list['ads_sdate'] == '0000-00-00 00:00:00', 'ads_idx']) # 227
ad_list[(ad_list['ads_sdate'] == '0000-00-00 00:00:00') & (ad_list['ads_edate'] == '0000-00-00 00:00:00')] # 227로 동일
# Out:
# 67          1306
# 81          1341
# 123         1448
# 124         1450
# 125         1452
#            ...
# 370994    372653
# 410717    412376
# 438476    440135
# 442294    443953
# 442588    444247
# Name: ads_idx, Length: 227, dtype: int64
#         ads_idx    ads_code  aff_idx  adv_idx  ads_type  ads_category  \
# 67         1306  lLU3dyqi3P       15       62         2             1
# 81         1341  rOAourUQgw        1      109         3             2
# 123        1448  oaHWT18w24       30       80         2             1
# 124        1450  bY9l99IGOw       30       80         1             1
# 125        1452  5GgMwttXai       30       80         2             1
# ...         ...         ...      ...      ...       ...           ...
# 370994   372653  KfzMhzCv4W        1      557         2             2
# 410717   412376  gL1vFwGwZR        1     1660         3             8
# 438476   440135  MEnre3naZI        1     1662         2             1
# 442294   443953  HiAARvqMP1        1     1670         2             1
# 442588   444247  dkAdH8Eh8H       57       84         3             8
#
#                                                ads_name  \
# 67                                  파이널 드래곤 나이츠 실행형_aos
# 81                                         프로야구 H2 사전예약
# 123                                        여명 for kakao
# 124                                                 몬스터
# 125                                             다음-Daum
# ...                                                 ...
# 370994                                          삼국지 올스타
# 410717                                            나두기업몰
# 438476                                             보스포커
# 442294                                            신트노트
# 442588  [답글] 대용량 토너! 미친 수분력! 72% 할인 깊다 깊어!ㅣ할인광36 [EN]_2
#
#                                              ads_icon_img  \
# 67      https://lh3.googleusercontent.com/KybE5bKufVNQ...
# 81      https://lh3.googleusercontent.com/NW3yM9glVbFq...
# 123     https://cdn-ad-static.buzzvil.com/uploads/1489...
# 124     https://d3aulf22blzf9p.cloudfront.net/uploads/...
# 125     https://buzzvil.akamaized.net/adfit.image/uplo...
# ...                                                   ...
# 370994                   https://i.imgur.com/a2hE0UL.jpeg
# 410717                   https://i.imgur.com/grRbX8G.jpeg
# 438476                    https://i.imgur.com/V9xckPU.png
# 442294                    https://i.imgur.com/AYHFLoW.png
# 442588  https://lh3.googleusercontent.com/lMoItBgdPPVD...
#
#                                               ads_summary ads_save_way  ...  \
# 67      3D 초대형 판타지 모바일 게임의 레볼루션! 파이널 드래곤 나이츠! \n이건 ARP...        최초 오픈  ...
# 81      지금 사전 예약해주세요~! \n선수뽑기 카드와 두둑한 지원금을 드립니다!!\n지금 ...      사전예약 완료  ...
# 123     4월 26일 대규모 업데이트!\n- 신규 직업 \"대검사\" 추가\n- 캐릭터 최고...        최초 오픈  ...
# 124     ▶한 번 시작하면 멈출 수 없는 액션\n- 고퀄리티 그래픽과 화려한 이펙트의 극한 ...           받기  ...
# 125     [서비스 접근 권한 안내]\n\n*다음앱에서 요청하는 모든 권한은 선택적 접근 권한...        최초 오픈  ...
# ...                                                   ...          ...  ...
# 370994  [참여 방법]\n1. 광고 참여 버튼 터치하여 마켓으로 이동\n2. App 최초 오...        최초 오픈  ...
# 410717  일반인 누구나 회원가입 가능!\n\n[참여 방법]\n1. 광고 참여 버튼 터치하여 ...           참여  ...
# 438476  [참여 방법]\n1. 광고 참여 버튼 터치하여 마켓으로 이동\n2. App 최초 오...        최초 오픈  ...
# 442294  [참여 방법]\n1. 광고 참여 버튼 터치하여 마켓으로 이동\n2. App 최초 오...        최초 오픈  ...
# 442588  ❌❌❌가이드 그대로 복사 붙혀넣을시 적립 불가합니다!❌❌❌ \n\n- 책임자님 완전...           참여  ...
#
#                   ads_sdate            ads_edate ads_age_min  ads_age_max  \
# 67      0000-00-00 00:00:00  0000-00-00 00:00:00           0          100
# 81      0000-00-00 00:00:00  0000-00-00 00:00:00           0          100
# 123     0000-00-00 00:00:00  0000-00-00 00:00:00           0          100
# 124     0000-00-00 00:00:00  0000-00-00 00:00:00           0          100
# 125     0000-00-00 00:00:00  0000-00-00 00:00:00           0          100
# ...                     ...                  ...         ...          ...
# 370994  0000-00-00 00:00:00  0000-00-00 00:00:00           0          100
# 410717  0000-00-00 00:00:00  0000-00-00 00:00:00           0          100
# 438476  0000-00-00 00:00:00  0000-00-00 00:00:00           0          100
# 442294  0000-00-00 00:00:00  0000-00-00 00:00:00           0          100
# 442588  0000-00-00 00:00:00  0000-00-00 00:00:00           0          100
#
#         ads_os_type  ads_contract_price  ads_reward_price  ads_order  \
# 67                2                 260               210     933000
# 81                7                1500              1200     659100
# 123               2                 200               180     933400
# 124               2                 160               150     996800
# 125               2                 200               180     933500
# ...             ...                 ...               ...        ...
# 370994            1                 280               180    2748100
# 410717            2                1200               800    2752600
# 438476            1                 280               180    2756700
# 442294            2                  10                10    2761400
# 442588            7                 200               150    2731100
#
#         ads_rejoin_type             regdate
# 67                 NONE 2017-04-06 14:13:53
# 81                 NONE 2017-03-24 10:29:58
# 123                NONE 2017-05-11 13:10:24
# 124                NONE 2017-05-11 13:13:47
# 125                NONE 2017-05-11 13:33:33
# ...                 ...                 ...
# 370994             NONE 2025-05-30 13:10:07
# 410717             NONE 2025-07-02 13:34:23
# 438476             NONE 2025-08-04 17:46:45
# 442294             NONE 2025-08-13 12:43:15
# 442588             NONE 2025-08-14 11:32:57
#
# [227 rows x 21 columns]

# %% [markdown]
# 광고 시작, 광고 끝 날짜는 날짜 타입으로 변환 어려워서 두고 등록일자만 변환

# %%
# # ad_list 저장
# ad_list.to_csv('수정2_광고목록.csv', index = False, encoding='utf-8')

# %%
# 수정2_광고목록으로 데이터 불러올 때는 바로 이 셀부터 시작!
ad_list = pd.read_csv('수정2_광고목록.csv')

# %% [markdown]
# ### 도메인 붙이기
#
# 위의 광고목록과 광고 참여 정보에 있는 광고 아이디만을 돌려서 광고의 도메인을 분류해서 붙임

# %%
# Google Bigquery에 올리기
# # row_id 컬럼 추가
# df = ad_list.head(200).reset_index().rename(columns={"index": "row_id"})

# # 업로드
# to_gbq(
#     df,
#     destination_table="test_ad_list.test",  # dataset.table 형식
#     project_id="sodium-primer-471002-n4",   # gcb 프로젝트 id 
#     if_exists="replace"  # append 도 가능
# )

# %% [markdown]
# # 광고적립

# %%
# 광고적립 파일 경로
path_sh = ''

# %% [markdown]
# # 광고참여

# %%
# 광고참여정보 파일 경로
path_sh = "/Users/t2023-m0052/Documents/GitHub/final_project/data/IVE_광고참여정보.csv"
ad_prpt = pd.read_csv(path_sh)
ad_prpt.head()
# Out:
#                                   click_key  ads_idx   dvc_idx  mda_idx  \
# 0  000000d54b9faad47ee99d6cd3cf53894dd4baa5   313780  61906528      539
# 1  000002b4d92f7648b455877c2676452efcd22a09   412426  34422806       58
# 2  0000057e97361ff3d0263aaecee34cfaa3ba30fb   443660  38366075      808
# 3  00000607f60139015da3ee1dd5499db3faa100dc   360192  61894110      539
# 4  0000066bc25d4a6d147c27326cf972a4de88024e   372307  61956954      539
#
#    pub_sub_rel_id  adv_price  contract_price  media_price  reward_price  \
# 0       144350110       6000            6000         4500          4500
# 1        46032732        180             180          170           170
# 2               1        170             170          120            60
# 3       144350110       6000            6000         4500          4500
# 4       144350110      15600           15600        11700         11700
#
#    reward_point   click_day  click_time           click_date     exp_day  \
# 0          4500  2025-08-17          21  2025-08-17 21:07:37  2025-09-16
# 1           170  2025-07-26           2  2025-07-26 02:18:24  2025-08-25
# 2            60  2025-08-12          18  2025-08-12 18:17:59  2025-09-11
# 3          4500  2025-08-17           3  2025-08-17 03:35:02  2025-09-16
# 4         11700  2025-08-18           8  2025-08-18 08:01:26  2025-09-17
#
#   network    carrier          user_ip
# 0       0        NaN    16.184.28.219
# 1     NaN        NaN     35.78.117.76
# 2    WIFI  SKTelecom      39.7.55.192
# 3       0        NaN  211.252.100.157
# 4       0        NaN     3.38.148.211

# %%
ad_prpt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16854865 entries, 0 to 16854864
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   click_key       object
#  1   ads_idx         int64
#  2   dvc_idx         int64
#  3   mda_idx         int64
#  4   pub_sub_rel_id  int64
#  5   contract_price  int64
#  6   media_price     int64
#  7   click_day       datetime64[ns]
#  8   click_time      int64
#  9   click_date      datetime64[ns]
#  10  exp_day         datetime64[ns]
#  11  network         object
#  12  user_ip         object
# dtypes: datetime64[ns](3), int64(7), object(3)
# memory usage: 1.6+ GB

# %% [markdown]
# ## 전처리

# %%
# 필요없는 열 제거
ad_prpt = ad_prpt.drop(['adv_price', 'reward_price', 'reward_point', 'carrier'], axis=1)
# 날짜 형식 변환
ad_prpt[['click_day', 'click_date', 'exp_day']] = ad_prpt[['click_day', 'click_date', 'exp_day']].apply(lambda x: pd.to_datetime(x))
ad_prpt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16854865 entries, 0 to 16854864
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   click_key       object
#  1   ads_idx         int64
#  2   dvc_idx         int64
#  3   mda_idx         int64
#  4   pub_sub_rel_id  int64
#  5   contract_price  int64
#  6   media_price     int64
#  7   click_day       datetime64[ns]
#  8   click_time      int64
#  9   click_date      datetime64[ns]
#  10  exp_day         datetime64[ns]
#  11  network         object
#  12  user_ip         object
# dtypes: datetime64[ns](3), int64(7), object(3)
# memory usage: 1.6+ GB

# %%
# network 변환
print(ad_prpt['network'].unique())
# network 숫자 정보로 변환
def change_network(x):
    if x == '2':
        return 'MOBILE'
    elif x == '4':
        return 'WIFI'
    else:
        return x
    
ad_prpt['network'] = ad_prpt['network'].apply(change_network)
# Out:
# ['0' nan 'WIFI' 'MOBILE' 'LTE' '2' 'ERROR' '4']

# %% [markdown]
# ## 창민님 추가 전처리 or 바로 적립이랑 조인한 거

# %% [markdown]
# # 시간별 광고 적립

# %%
# 광고참여정보 파일 경로
path_sh = ''
