# %%
import pandas as pd

# %%
rewards = pd.read_csv("/Users/Jiwon/Documents/GitHub/final_project/data/IVE_광고적립.csv")

# %%
rewards
# Out:
#            rwd_idx  ads_idx    ads_code  mda_idx  pub_sub_rel_id   dvc_idx  \
# 0        238304818   413490  CFZ6lzEmeD       22        27496512  32947806
# 1        238304829   413490  CFZ6lzEmeD       22        27496512  47387244
# 2        238304816   413490  CFZ6lzEmeD       22        27496512  32425124
# 3        238304817   413490  CFZ6lzEmeD       22        27496513  34006545
# 4        238304802   133653  rl8ud4uNQC      801               1  56867331
# ...            ...      ...         ...      ...             ...       ...
# 1475026  239780599   356956  1UNE1La9yv      270               1  35431157
# 1475027  239780621   445907  0gEJGntDo3      794               1  62076634
# 1475028  239780617   446855  yrwq08KCov      563               1  60605730
# 1475029  239780609   446837  2hznDD8Yx3      371               1  46271340
# 1475030  239780612   356956  1UNE1La9yv      270               1  61667811
#
#                                         advid  \
# ...

# %%
ads = pd.read_csv("/Users/Jiwon/Documents/GitHub/final_project/data/IVE_광고목록.csv")
# Out:
# /var/folders/6n/tjcbrygj54s39y61m4r7ymrr0000gq/T/ipykernel_88157/1411436255.py:1: DtypeWarning: Columns (12,13,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   ads = pd.read_csv("/Users/Jiwon/Documents/GitHub/final_project/data/IVE_광고목록.csv")

# %%
pd.set_option('display.float_format', lambda x: f'{x:f}')

# %%
print("===== 고유값 개수 =====")
print (rewards.nunique())
print()

print("===== null 값 개수 =====")
print("null 개수 : ", rewards.isnull().sum())
print("null 비중 : ", rewards.isnull().mean())
print("\n 광고 식별자만 null 값 가짐\n")

print("===== info =====")
print(rewards.info())
print()

print("===== decribe =====")
print(rewards.describe())
# Out:
# ===== 고유값 개수 =====
# rwd_idx           1475031
# ads_idx              8379
# ads_code            18701
# mda_idx               174
# pub_sub_rel_id       4062
# dvc_idx            642059
# advid              642164
# click_key         1475031
# show_cost             178
# adv_cost              177
# rwd_cost              343
# earn_cost             282
# click_date         881394
# regdate            871979
# ctit                18551
# dtype: int64
#
# ===== null 값 개수 =====
# null 개수 :  rwd_idx              0
# ads_idx              0
# ads_code             0
# mda_idx              0
# pub_sub_rel_id       0
# dvc_idx              0
# advid             7171
# click_key            0
# show_cost            0
# adv_cost             0
# rwd_cost             0
# earn_cost            0
# click_date           0
# regdate              0
# ctit                 0
# dtype: int64
# null 비중 :  rwd_idx          0.000000
# ads_idx          0.000000
# ads_code         0.000000
# ...

# %%
# adv_cost(광고 소진금액), earn_cost(매체사 수익금액) 만 남기기

rewards = rewards.drop(columns=['show_cost','rwd_cost'])

# %%
rewards.describe()
# Out:
#                rwd_idx        ads_idx        mda_idx   pub_sub_rel_id  \
# count   1475031.000000 1475031.000000 1475031.000000   1475031.000000
# mean  239042983.839559  420134.498482     419.332570  25797059.266720
# std      425938.446114   82625.689183     265.017095  44503654.045392
# min   238304802.000000    9716.000000      12.000000         1.000000
# 25%   238674222.500000  435909.000000     303.000000         1.000000
# 50%   239043054.000000  440525.000000     396.000000         1.000000
# 75%   239411848.500000  444350.000000     563.000000  33306660.000000
# max   239780622.000000  446909.000000    1061.000000 144682688.000000
#
#               dvc_idx       adv_cost      earn_cost           ctit
# count  1475031.000000 1475031.000000 1475031.000000 1475031.000000
# mean  50579799.805650     391.075579     159.297658    1060.343629
# std   11897231.126098    4641.356824     321.611117   18927.725319
# min          0.000000       0.000000       1.000000       0.000000
# ...

# %%
'''
rwd_idx : 적립 row 고유키
ads_idx : 광고 키
ads_code : 광고 코드
mda_idx : 광고를 소비한 매체 번호
pub_sub_re_id : 광고를 소비한 매체의 하위 매체
dvc_idx : 디바이스키
advid : 디바이스 아이디
click_key : 클릭키
adv_cost : 광고 단가
earn_cost : 매체사 단가
click_date : 광고참여일시
regdate : 광고 참여완료일시
ctit : 지연시간(초)
'''
# Out:
# '\nrwd_idx : 적립 row 고유키\nads_idx : 광고 키\nads_code : 광고 코드\nmda_idx : 광고를 소비한 매체 번호\npub_sub_re_id : 광고를 소비한 매체의 하위 매체\ndvc_idx : 디바이스키\nadvid : 디바이스 아이디\nclick_key : 클릭키\nadv_cost : 광고 단가\nearn_cost : 매체사 단가\nclick_date : 광고참여일시\nregdate : 광고 참여완료일시\nctit : 지연시간(초)\n'

# %%
# 날짜관련데이터 테이트타임으로 타입 변환

rewards['click_date'] = pd.to_datetime(rewards['click_date'])
rewards['regdate'] = pd.to_datetime(rewards['regdate'])

# %%
rewards
# Out:
#            rwd_idx  ads_idx    ads_code  mda_idx  pub_sub_rel_id   dvc_idx  \
# 0        238304818   413490  CFZ6lzEmeD       22        27496512  32947806
# 1        238304829   413490  CFZ6lzEmeD       22        27496512  47387244
# 2        238304816   413490  CFZ6lzEmeD       22        27496512  32425124
# 3        238304817   413490  CFZ6lzEmeD       22        27496513  34006545
# 4        238304802   133653  rl8ud4uNQC      801               1  56867331
# ...            ...      ...         ...      ...             ...       ...
# 1475026  239780599   356956  1UNE1La9yv      270               1  35431157
# 1475027  239780621   445907  0gEJGntDo3      794               1  62076634
# 1475028  239780617   446855  yrwq08KCov      563               1  60605730
# 1475029  239780609   446837  2hznDD8Yx3      371               1  46271340
# 1475030  239780612   356956  1UNE1La9yv      270               1  61667811
#
#                                         advid  \
# ...

# %%
rewards[rewards['ctit']>=2000000]
# Out:
#           rwd_idx  ads_idx    ads_code  mda_idx  pub_sub_rel_id   dvc_idx  \
# 18955   239719827   168828  CxZ48rIVgS      343        11082141  58340625
# 41364   239268085   384133  RAMxbBaXMS      539       144296957  60136156
# 64330   239669021   431126  FS6DsZPo9z      270               1  54511321
# 113898  239568581    96793  I8Px5zK2kJ      270               1  53928376
# 148716  239717943   364671  c9GnZgmq9s      645               1  61752825
# 191244  239759483   372307  oj212GwFsd       14       140199523  55053779
#
#                                        advid  \
# 18955   eeca111d-28a8-4c4b-a1ec-b42a283a3845
# 41364   9f1efe9a-2bc1-4b54-9c92-573c55791a60
# 64330   5efa8110-f3a4-443e-b674-a1b944674470
# 113898  cbcf2037-b4e8-4bd2-9857-57e00f62395a
# 148716  0e4c05ce-9c50-4082-935b-90f923bf03b3
# 191244  889ae5a8-830f-42ff-8d69-dcc7c8f39f7d
#
#                                        click_key  adv_cost  earn_cost  \
# ...

# %%
rewards[rewards['mda_idx']==539]
# Out:
#            rwd_idx  ads_idx    ads_code  mda_idx  pub_sub_rel_id   dvc_idx  \
# 452      238306623   391165  VfoZmzvPFX      539       138362162  61072839
# 459      238305587   412426  yuRe4YoPuZ      539       135848306  44860380
# 465      238306894   391165  VfoZmzvPFX      539       144303596  60191722
# 737      238305473   412426  yuRe4YoPuZ      539         2563205  61698624
# 760      238305515   412426  yuRe4YoPuZ      539       138362162  61686819
# ...            ...      ...         ...      ...             ...       ...
# 1474861  239780488   334542  3RWdqVuBes      539       138362162  60953002
# 1474887  239780498   334542  3RWdqVuBes      539       138362162  61955996
# 1474941  239780602   334543  dPdD08CEBi      539       138362162  46706738
# 1474942  239780553   334540  3klpQP05kc      539       138362162  60953002
# 1474944  239780568   334543  dPdD08CEBi      539       138362162  56852596
#
#                                         advid  \
# ...

# %%
vote = ads[ads['ads_idx']==127906]

# %%
vote.to_csv("vote_sample.csv")

# %%
ads[ads['ads_idx']==441013]
# Out:
#         ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  \
# 439354   441013  DBnAFWELCR        1     1666  1212387         3
#
#         ads_category             ads_name           ads_search  \
# 439354            13  포춘쿠키 (1일 1회 재참여 가능)  포춘쿠키 (1일 1회 재참여 가능)
#
#                            ads_icon_img  ... ads_age_min ads_age_max  \
# 439354  https://i.imgur.com/WXJLV3Q.png  ...           0         100
#
#        ads_os_type ads_contract_price ads_reward_price ads_order  \
# 439354           7                  2                2   2764300
#
#               ads_rejoin_type ads_require_adid              regdate delyn
# 439354  ADS_CODE_DAILY_UPDATE                N  2025-08-06 10:12:22     N
#
# [1 rows x 30 columns]

# %%
device = rewards.groupby('dvc_idx').agg({'advid':'nunique'}).reset_index()

# %%
device
# Out:
#          dvc_idx  advid
# 0              0      0
# 1           1954      1
# 2           2048      1
# 3           4222      1
# 4          12412      1
# ...          ...    ...
# 642054  62076627      1
# 642055  62076629      1
# 642056  62076631      1
# 642057  62076632      1
# 642058  62076634      1
#
# [642059 rows x 2 columns]

# %%
ads[ads['ads_idx']==435921]
# Out:
#         ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  \
# 434262   435921  yVK2kd2LpI        1      618  1202083         9
#
#         ads_category       ads_name     ads_search  \
# 434262             6  ﻿드래곤 블러드: 레이더  ﻿드래곤 블러드: 레이더
#
#                            ads_icon_img  ... ads_age_min ads_age_max  \
# 434262  https://i.imgur.com/SAdWfTV.png  ...           0         100
#
#        ads_os_type ads_contract_price ads_reward_price ads_order  \
# 434262           2                  0              286   2735400
#
#        ads_rejoin_type ads_require_adid              regdate delyn
# 434262            NONE                N  2025-07-24 15:20:11     N
#
# [1 rows x 30 columns]

# %%
rewards[rewards['adv_cost']<=rewards['earn_cost']]
# Out:
#            rwd_idx  ads_idx    ads_code  mda_idx  pub_sub_rel_id   dvc_idx  \
# 18       238396237   435921  yVK2kd2LpI      270               1  61441961
# 86       238398011   435921  yVK2kd2LpI      270               1  47952092
# 130      238406316   435921  yVK2kd2LpI      270               1  48174136
# 487      238397157   435921  yVK2kd2LpI      270               1  48801874
# 3838     238396165   350415  9VIbFmxcD8      270               1  53561962
# ...            ...      ...         ...      ...             ...       ...
# 1474648  239780194    22081  6KpGaxV4ot      270               1  60206234
# 1474668  239780213   441013  DBnAFWELCR      371               1  58742443
# 1474669  239780222   435910  wLM4t3Yi65      787               1         0
# 1474757  239780315   435910  wLM4t3Yi65      785               1  52937461
# 1474782  239780344   441013  DBnAFWELCR       54       144682688  62076494
#
#                                         advid  \
# ...

# %%
ads = pd.read_csv("/Users/Jiwon/Documents/GitHub/final_project/data/IVE_광고목록.csv")
# Out:
# /var/folders/6n/tjcbrygj54s39y61m4r7ymrr0000gq/T/ipykernel_88157/1411436255.py:1: DtypeWarning: Columns (12,13,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   ads = pd.read_csv("/Users/Jiwon/Documents/GitHub/final_project/data/IVE_광고목록.csv")

# %%
ads[ads['ads_idx']==435921]
# Out:
#         ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  \
# 434262   435921  yVK2kd2LpI        1      618  1202083         9
#
#         ads_category       ads_name     ads_search  \
# 434262             6  ﻿드래곤 블러드: 레이더  ﻿드래곤 블러드: 레이더
#
#                            ads_icon_img  ... ads_age_min ads_age_max  \
# 434262  https://i.imgur.com/SAdWfTV.png  ...           0         100
#
#        ads_os_type ads_contract_price ads_reward_price ads_order  \
# 434262           2                  0              286   2735400
#
#        ads_rejoin_type ads_require_adid              regdate delyn
# 434262            NONE                N  2025-07-24 15:20:11     N
#
# [1 rows x 30 columns]

# %%
ads[ads['ads_idx']==436643]
# Out:
#         ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  \
# 434984   436643  drcbDlOweT       81     1597  1222152         3
#
#         ads_category              ads_name  \
# 434984             5  PLAYTIME - 게임으로 돈 벌기
#
#                                        ads_search  \
# 434984  PLAYTIME - 게임으로 돈 벌기,pro.cashtree,2612429
#
#                                              ads_icon_img  ... ads_age_min  \
# 434984  https://cdn.mychips.io/thumbnail/28a64816c3edd...  ...           0
#
#        ads_age_max ads_os_type ads_contract_price ads_reward_price ads_order  \
# 434984         100           2              13320            10000   2467400
#
#        ads_rejoin_type ads_require_adid              regdate delyn
# 434984            NONE                Y  2025-07-25 18:53:56     N
#
# [1 rows x 30 columns]

# %%
ads[ads['delyn']=='Y']
# Out:
#         ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  \
# 7          1142  zQ76Efhdj3        9        0        0         3
# 14         1180  ngo2OKJYga        0       32        0         1
# 26         1220  YAxjTA2iP5        1       64        0         1
# 456        2039  28SaZM6shd        6       10     6652         3
# 475        2058  yGoECaidUz        1       84        0         1
# ...         ...         ...      ...      ...      ...       ...
# 439413   441072  VPtZb3BS8m       57       84        0         3
# 440342   442001  E5RRhoL1eT        8       50        0         1
# 442692   444351  dY7jZ77yka       15     1672  1218845         1
# 442693   444352  MnWcfxDVbK       15     1672  1218853         2
# 443038   444697  EbBjfvoNFa       48     1673        0         3
#
#         ads_category                      ads_name  \
# 7                  0  데저트스톰_사전예약(desert_storm_cpa)
# 14                 1                        지하철종결자
# ...

# %%
ads['ads_rejoin_type'].nunique()
# Out:
# 3

# %%
rewards.to_csv("수정_광고적립.csv", index=False)

# %%
ads['ads_sdate'] = pd.to_datetime(ads['ads_sdate'],errors='coerce')

# %%
ads['ads_sdate']
# Out:
# 0        2016-12-01 00:00:00
# 1        2016-12-29 00:00:00
# 2        2016-12-29 00:00:00
# 3        2017-01-01 00:00:00
# 4        2017-01-01 00:00:00
#                  ...
# 445255   2025-08-25 11:08:15
# 445256   2025-08-25 11:12:12
# 445257   2025-08-25 11:12:16
# 445258   2025-08-25 11:00:00
# 445259   2025-08-25 11:00:00
# Name: ads_sdate, Length: 445260, dtype: datetime64[ns]

# %%
ads_head = ads.head(200)

# %%
ads_head.to_csv("광고목록.csv")

# %%
ads
# Out:
#         ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  \
# 0           160  tr71opm6C1        6       10    13604         1
# 1           284  xlNpfkgtLX        6       10    13605         1
# 2           292  7Hj8V5QKiy        6       10    13606         1
# 3           304  1RfxHJcuEe        6       10    13607         2
# 4           306  l3GyilYEVk        6       10    23543         1
# ...         ...         ...      ...      ...      ...       ...
# 445255   446914  qy1HUatIL9       85     1631  1223705         3
# 445256   446915  UKnGFJUnmg       84     1623  1223706         3
# 445257   446916  g3lUg3nuxR       86     1655  1223708         3
# 445258   446917  0GLHsRVZNv       57       84  1223711         3
# 445259   446918  k2YLVkNAuO       57       84  1223710         3
#
#         ads_category                                          ads_name  \
# 0                  1                                          리니지레드나이츠
# ...

# %%
delyn = ads[ads['delyn']=='Y']

# %%
delyn.to_csv("삭제여부y.csv")

# %%
rewards[rewards['ads_idx']==17793]
# Out:
# Empty DataFrame
# Columns: [rwd_idx, ads_idx, ads_code, mda_idx, pub_sub_rel_id, dvc_idx, advid, click_key, adv_cost, earn_cost, click_date, regdate, ctit]
# Index: []

# %% [markdown]
# # 광고 참여 정보 분석

# %%
participate = pd.read_csv("/Users/Jiwon/Documents/GitHub/final_project/Jiwon/수정_광고참여정보.csv")

# %%
web = participate[participate['dvc_idx']==0]

# %%
web['mda_idx'].nunique()
# Out:
# 21

# %%
web
# Out:
#                                          click_key  ads_idx  dvc_idx  mda_idx  \
# 478       00020a6283bd4ed1782a6761eb385472ac54522f   130275        0      980
# 697       0002f2005851ccb5c7de76b397ea20ef029f1490   444244        0      654
# 752       0003294b3c83b0a68b3395ac71ab1d81488c32d0   444244        0      654
# 1645      00069b1235251c14f3bf1dd8179a80e7894b2cdd    73878        0      654
# 2481      0009db33d369bab564bba210f35257ec5679fe32    73878        0      654
# ...                                            ...      ...      ...      ...
# 16853262  fff9ad76da724e0449c887fef42be627fa6f9487    73878        0      654
# 16853290  fff9bf88cced6a10ac415a423e9e487690ace50b   429485        0      980
# 16854286  fffdbb9e7d038ce2da77812f7d779e71105417ec    73878        0      654
# 16854439  fffe52a04fd8531fd9e545359ae255d688af26a9    73878        0      654
# 16854729  ffff85abde1cbbfa4ba9d16c8af82f1035cce925   444244        0      654
#
# ...

# %%
web['mda_idx'].unique()
# Out:
# array([ 980,  654,  714,  540,  583,  755, 1055, 1042,  769,  480,  978,
#         787,  481,   73, 1023,  437, 1050,  539, 1049,  398,  710])

# %%
# Out:
# array([0])

# %%
participate[participate['mda_idx']==980]['dvc_idx'].unique()
# Out:
# 1

# %%
participate[participate['mda_idx']==654]['dvc_idx'].unique()
# Out:
# 1

# %%
participate[participate['mda_idx']==1055]['dvc_idx'].unique()
# Out:
# array([0])

# %%
participate[participate['mda_idx']==787]['dvc_idx'].unique()
# Out:
# array([0])

# %%
web_info = web.merge(ads, on='ads_idx', how='left')

# %%
pd.set_option('display.max_columns', None)  # 모든 컬럼 표시
pd.set_option('display.width', None)        # 가로 폭 제한 없음
pd.set_option('display.max_colwidth', None) # 컬럼 내용 길이 제한 없음

# %%
web_info['ads_name'].unique()
# Out:
# array(['[블랙] 30만 투표권 + 4만 보너스 + 9,000 등급 보너스', '국가통합바이오빅데이터구축사업 참여 사전신청',
#        '굿툰 7일 무료체험', '실버 등급 패키지', '류현진 데이렉스 엑소좀겔 마사지 크림 50g',
#        'KWDA 가챠이벤트 1만 투표권', '[일반] 10만 투표권 + 1만 보너스',
#        '[일반] 30만 투표권 + 4만 보너스', '[일반] 5만 투표권', '[일반] 1만 투표권', '로보주식플러스',
#        '[쎄븐업플러스]철갑상어 건강즙 70ml 30포', '블랙 등급 패키지',
#        '짐스낵 다이어트 간식 프로틴 단백질 쿠키 과자', '[동원] 리챔 더블라이트 200g X 8캔',
#        '골드 등급 패키지', '[실버] 5만 투표권 + 500 등급 보너스',
#        '면세점입점 나틴다 승무원팩트 실키커버 21호', '[록키스] 아쿠아 부스트 옴므 올인원 2개',
#        '[골드] 30만 투표권 + 4만 보너스 + 6,000 등급 보너스', 'H.point 회원가입',
#        '[블랙] 5만 투표권 + 1,500 등급 보너스', '충청남도 X(트위터)',
#        '굿매너 뽑아쓰는 키친타올 3겹(100매×9팩)',
#        '[실버] 10만 투표권 + 1만 보너스 + 1,000 등급 보너스', '[실버] 1만 투표권 + 100 등급 보너스',
#        '원데이즈유 콜라겐 하이드로겔 아이패치 60매', '[블랙] 10만 투표권 + 1만 보너스 + 3,000 등급 보너스',
#        '[실버] 30만 투표권 + 4만 보너스 + 3,000 등급 보너스', '고잔갈비 안산본점',
#        '오스틴제약 비타 이뮨 플래티넘 골드 15병', '[뉴바이오]덴타골드치약 200gx2개 세트',
#        '매드라운드 에고이즘 오드퍼퓸 30ml', '아론샵 홀드맥스 헤어젤 120ml',
# ...

# %%
result = web_info.groupby('mda_idx')['ads_name'].agg(list).reset_index()

# %%
result
# Out:
#     mda_idx  \
# 0        73
# 1       398
# 2       437
# 3       480
# 4       481
# 5       539
# 6       540
# 7       583
# 8       654
# 9       710
# 10      714
# 11      755
# 12      769
# 13      787
# 14      978
# 15      980
# 16     1023
# 17     1042
# 18     1049
# 19     1050
# 20     1055
#
# ...

# %%
rewards[rewards['dvc_idx']==0]['mda_idx'].unique()
# Out:
# array([ 980,  714,  654,  978,  480,  539,  540, 1050,  481,  787])

# %%
web_info[web_info['mda_idx']==978]
# Out:
#                                       click_key  ads_idx  dvc_idx  mda_idx  \
# 748    04752be1e262ed13c2bfad75d6089d3a4deec2ea   443482        0      978
# 1250   078c08b8d7e9b743d74b3d4b81ea3a439843157f   438971        0      978
# 1279   07bd20cd0e5edff06636d8c1083c38c40ef8d066   355220        0      978
# 2133   0cd45eb88da49cb0c53e30a609ebadecdd65a2ee   440592        0      978
# 4013   17c2212ed798e1576eb90bb710055af6bc2c4123   439258        0      978
# ...                                         ...      ...      ...      ...
# 41134  f33342a255d50a775c0e511dff7548b1756b2051   439462        0      978
# 41233  f3abac6956ce6719cbd629242eb49fa5b5d9503d   440517        0      978
# 41419  f4cd76bfc85bda421b06dc8bedf6a141affa7c80   439256        0      978
# 41974  f801f538f3422ec42c8891658495595a7c2a6369   437744        0      978
# 42306  f9dc1539eeb05b9fcf977bd2290d3e31f4275f0e    17056        0      978
#
# ...

# %% [markdown]
# # Edate 000000

# %%
pd.reset_option('display.max_columns')
pd.reset_option('display.width')
pd.reset_option('display.max_colwidth')

# %%
# drop dylen == y
# sdate 0000 edate 0000

# %%
delyn = ads[ads['delyn']!='Y']

# %%
edatezero = delyn[delyn['ads_edate']=='0000-00-00 00:00:00']

# %%
df = edatezero.merge(participate, on='ads_idx', how='left')

# %%
edatezero
# Out:
#         ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  \
# 67         1306  lLU3dyqi3P       15       62        0         2
# 81         1341  rOAourUQgw        1      109        0         3
# 123        1448  oaHWT18w24       30       80        0         2
# 124        1450  bY9l99IGOw       30       80        0         1
# 125        1452  5GgMwttXai       30       80        0         2
# ...         ...         ...      ...      ...      ...       ...
# 370994   372653  KfzMhzCv4W        1      557        0         2
# 410717   412376  gL1vFwGwZR        1     1660        0         3
# 438476   440135  MEnre3naZI        1     1662        0         2
# 442294   443953  HiAARvqMP1        1     1670        0         2
# 442588   444247  dkAdH8Eh8H       57       84        0         3
#
#         ads_category                                         ads_name  \
# 67                 1                              파이널 드래곤 나이츠 실행형_aos
# ...

# %%
ads[ads['ads_name'] == '프로야구 H2 사전예약']
# Out:
#     ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  ads_category  \
# 81     1341  rOAourUQgw        1      109        0         3             2
#
#         ads_name      ads_search  \
# 81  프로야구 H2 사전예약  프로야구 H2 사전예약,,
#
#                                          ads_icon_img  ... ads_age_min  \
# 81  https://lh3.googleusercontent.com/NW3yM9glVbFq...  ...           0
#
#    ads_age_max ads_os_type ads_contract_price ads_reward_price ads_order  \
# 81         100           7               1500             1200    659100
#
#    ads_rejoin_type ads_require_adid              regdate delyn
# 81            NONE                Y  2017-03-24 10:29:58     N
#
# [1 rows x 30 columns]

# %%
df['ads_idx'].nunique()
# Out:
# 227

# %%
df
# Out:
#      ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  ads_category  \
# 0       1306  lLU3dyqi3P       15       62        0         2             1
# 1       1341  rOAourUQgw        1      109        0         3             2
# 2       1448  oaHWT18w24       30       80        0         2             1
# 3       1450  bY9l99IGOw       30       80        0         1             1
# 4       1452  5GgMwttXai       30       80        0         2             1
# ..       ...         ...      ...      ...      ...       ...           ...
# 233   372653  KfzMhzCv4W        1      557        0         2             2
# 234   412376  gL1vFwGwZR        1     1660        0         3             8
# 235   440135  MEnre3naZI        1     1662        0         2             1
# 236   443953  HiAARvqMP1        1     1670        0         2             1
# 237   444247  dkAdH8Eh8H       57       84        0         3             8
#
#                                             ads_name  \
# ...

# %%
df[df['mda_idx'].notna()]
# Out:
#      ads_idx    ads_code  aff_idx  adv_idx  sch_idx  ads_type  ads_category  \
# 201   163147  kmATsHYwmH       76     1355   613872         3             5
# 202   163147  kmATsHYwmH       76     1355   613872         3             5
# 203   163147  kmATsHYwmH       76     1355   613872         3             5
# 204   163147  kmATsHYwmH       76     1355   613872         3             5
# 205   163147  kmATsHYwmH       76     1355   613872         3             5
# 206   163147  kmATsHYwmH       76     1355   613872         3             5
# 207   163147  kmATsHYwmH       76     1355   613872         3             5
# 208   163147  kmATsHYwmH       76     1355   613872         3             5
# 209   163147  kmATsHYwmH       76     1355   613872         3             5
# 210   163147  kmATsHYwmH       76     1355   613872         3             5
# 211   163147  kmATsHYwmH       76     1355   613872         3             5
# ...

# %%
participate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16854865 entries, 0 to 16854864
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   click_key       object
#  1   ads_idx         int64
#  2   dvc_idx         int64
#  3   mda_idx         int64
#  4   pub_sub_rel_id  int64
#  5   contract_price  int64
#  6   media_price     int64
#  7   click_day       object
#  8   click_time      int64
#  9   click_date      object
#  10  exp_day         object
#  11  network         object
#  12  user_ip         object
# dtypes: int64(7), object(6)
# memory usage: 1.6+ GB

# %%
participate[participate['ads_idx']==321237]
# Out:
# Empty DataFrame
# Columns: [click_key, ads_idx, dvc_idx, mda_idx, pub_sub_rel_id, contract_price, media_price, click_day, click_time, click_date, exp_day, network, user_ip]
# Index: []
